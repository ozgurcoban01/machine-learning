# %%
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D

# %%
x = np.arange(0.3, 3, 0.45)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sinüs ")
plt.xlabel("X ekseni")
plt.ylabel("Y ekseni")
plt.show()

# %%
x = np.random.rand(20)
y = np.random.rand(20)
colors = np.random.rand(20)
sizes = np.random.randint(20, 3200, 20)
plt.scatter(x, y, c=colors, s=sizes)
plt.title("Point Chart")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
data = np.random.randn(30)

plt.hist(data, bins=20)
plt.title("Test")
plt.xlabel("Alt Değer")
plt.ylabel("Yan Değer")
plt.show()

# %%
x = ['Ali', 'Ayşe', 'Özgür']
y = np.random.randint(1, 100, 3)

plt.bar(x, y)
plt.title("Not Grafik")
plt.xlabel("Sıralama")
plt.ylabel("Notlar")
plt.show()

# %%
sizes = [85, 30, 20, 60, 15, 79]

plt.pie(sizes)
plt.title("Not Dağılım")
plt.show()

# %%
x = np.arange(-3, 1, 0.25)
y = np.arange(-3, 1, 0.25)
x, y = np.meshgrid(x, y)
r = np.sqrt(x**2 + y**2)
z = np.sin(r)


r = np.sqrt(x**2 + y**2)
z = np.sin(r)

fig = plt.figure()

ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z)
ax.set_title("3D Graphics")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")

plt.show()
